# %%
import os
import subprocess

import matplotlib.pyplot as plt
import torch

CUDA = "0"

for num_bases in (120, 160):
    for num_sessions in (25,):
        # Run the generation script
        cmd = [
            "python", "tma_standalone.py",
            str(num_bases),
            str(num_sessions),
            CUDA,
        ]
        
        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1
        )
        
        # Stream output line by line
        for line in process.stdout:
            print(line, end='')       # print without adding extra newline
            sys.stdout.flush()        # ensure it shows immediately in Jupyter
        
        process.wait()  # wait for completion
# Out:
# ----------- 120 25 0 --
# Batch shapes:
# Train
# torch.Size([1250, 20, 93])
# torch.Size([1250, 20, 93])
# torch.Size([1250, 20, 93])
# torch.Size([1250, 20, 93])
# Test
# torch.Size([1250, 20, 93])
# torch.Size([1250, 20, 93])
# Building and fitting normalizers...
# Building and warm starting AEs...
# Building TBFM...
# BOOM! Dino DNA!
# ---- 0 0.6682636737823486 1.0527258515357971 -0.05234039884060621 0.06323551014065742
# ---- 1000 0.40272125601768494 0.7126835286617279 0.36665219128131865 0.3877953439950943
# ---- 2000 0.38176408410072327 0.6947050094604492 0.39989876419305803 0.40339232981204987
# ---- 3000 0.37231793999671936 0.6807527840137482 0.4148629033565521 0.4163299947977066
# ---- 4000 0.3686952590942383 0.6773741245269775 0.4199516347050667 0.41882601380348206
# ---- 5000 0.3669549524784088 0.6736645102500916 0.42310533821582796 0.4226166307926178
# ---- 6000 0.36877432465553284 0.6741910874843597 0.4199394643306732 0.42189091444015503
# ---- 7000 0.36744171380996704 0.672102689743042 0.4223743689060211 0.42264340817928314
# ---- 8000 0.3727395236492157 0.6815879344940186 0.4143054682016373 0.41698718070983887
# ---- 9000 0.37158191204071045 0.6804064214229584 0.41600269079208374 0.41881783306598663

# %%
results = torch.load("test/80_25/r_nf_1.torch")
print(sum(results["final_test_r2s"].values()) / len(results["final_test_r2s"]))
# Out:
# 0.4294154116511345

# %%
for idx, trr2 in enumerate(results["train_r2s"]):
    print(idx, trr2, results["test_r2s"][idx])
# Out:
# 0 (0, -0.04576081235893071) (0, 0.03677775524556637)
# 1 (1000, 0.4206536138057709) (1000, 0.41586580872535706)
# 2 (2000, 0.42016273021698) (2000, 0.41449175775051117)
# 3 (3000, 0.43080237329006194) (3000, 0.42330314218997955)
# 4 (4000, 0.44649612963199614) (4000, 0.4344836175441742)
# 5 (5000, 0.4527998483181) (5000, 0.44155316054821014)
# 6 (6000, 0.4520311188697815) (6000, 0.44099046289920807)
# 7 (7000, 0.45367172539234163) (7000, 0.4428030848503113)
# 8 (8000, 0.44527297616004946) (8000, 0.43706586956977844)
# 9 (9000, 0.26449533715844153) (9000, 0.3556627929210663)
# 10 (10000, 0.44128374099731443) (10000, 0.4301939606666565)
# 11 (11000, 0.4407802307605743) (11000, 0.4268030673265457)
# 12 (12000, 0.44353609561920165) (12000, 0.4290682524442673)

# %%
print(results["train_losses"])
# Out:
# [(0, 0.6645572781562805), (1, 0.6878139972686768), (2, 0.7959237694740295), (3, 0.8739128708839417), (4, 0.817669153213501), (5, 0.6755298376083374), (6, 0.7837067246437073), (7, 0.8510329127311707), (8, 0.6067635416984558), (9, 0.646509051322937), (10, 0.7577709555625916), (11, 0.8277722597122192), (12, 0.5879648327827454), (13, 0.6232159733772278), (14, 0.7290633320808411), (15, 0.7969694137573242), (16, 0.5669487118721008), (17, 0.5984735488891602), (18, 0.7045691013336182), (19, 0.7728095054626465), (20